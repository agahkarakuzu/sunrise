# %%
from bids import BIDSLayout
import os

# %%
data_path = './Image'

# %%
layout = BIDSLayout(data_path)
# Out:
# /Users/agah/opt/anaconda3/envs/jbnew/lib/python3.6/site-packages/bids/layout/models.py:152: FutureWarning: The 'extension' entity currently excludes the leading dot ('.'). As of version 0.14.0, it will include the leading dot. To suppress this warning and include the leading dot, use `bids.config.set_option('extension_initial_dot', True)`.
#   FutureWarning)

# %%
df = layout.to_df()
df
# Out:
# entity                                               path acquisition  \
# 0       /Users/agah/Desktop/RTHDEV/Applications/norah_...         NaN
# 1       /Users/agah/Desktop/RTHDEV/Applications/norah_...         NaN
# 2       /Users/agah/Desktop/RTHDEV/Applications/norah_...         NaN
# 3       /Users/agah/Desktop/RTHDEV/Applications/norah_...      chord1
# 4       /Users/agah/Desktop/RTHDEV/Applications/norah_...      chord1
# 5       /Users/agah/Desktop/RTHDEV/Applications/norah_...      chord2
# 6       /Users/agah/Desktop/RTHDEV/Applications/norah_...      chord2
# 7       /Users/agah/Desktop/RTHDEV/Applications/norah_...      chord3
# 8       /Users/agah/Desktop/RTHDEV/Applications/norah_...      chord3
# 9       /Users/agah/Desktop/RTHDEV/Applications/norah_...      chord4
# 10      /Users/agah/Desktop/RTHDEV/Applications/norah_...      chord4
# 11      /Users/agah/Desktop/RTHDEV/Applications/norah_...         NaN
#
# entity datatype extension  session subject        suffix
# 0           NaN      json      NaN     NaN   description
# 1           NaN      json      NaN     NaN  participants
# 2           NaN       tsv      NaN     NaN  participants
# 3          anat      json  sunrise   ismrm           T1w
# 4          anat    nii.gz  sunrise   ismrm           T1w
# 5          anat      json  sunrise   ismrm           T1w
# 6          anat    nii.gz  sunrise   ismrm           T1w
# 7          anat      json  sunrise   ismrm           T1w
# 8          anat    nii.gz  sunrise   ismrm           T1w
# 9          anat      json  sunrise   ismrm           T1w
# 10         anat    nii.gz  sunrise   ismrm           T1w
# 11          NaN       NaN      NaN     NaN           NaN

# %%
import nibabel as nib

# %%
aa = layout.get(subject='ismrm', extension='nii.gz', suffix='T1w', return_type='file', acquisition='chord1')

# %%
chord1 = nib.load(''.join(aa))

# %%
chord1.shape
# Out:
# (100, 100)

# %%
import plotly.express as px

px.imshow(chord1.get_fdata())
# Out:
# <div>
#
#
#             <div id="9599fcd4-f950-4589-b6cc-d61c0ae4a30f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9599fcd4-f950-4589-b6cc-d61c0ae4a30f")) {
#                     Plotly.newPlot(
#                         '9599fcd4-f950-4589-b6cc-d61c0ae4a30f',
#                         [{"coloraxis": "coloraxis", "hovertemplate": "x: %{x}<br>y: %{y}<br>color: %{z}<extra></extra>", "type": "heatmap", "z": [[1.5242044925689697, 1.539243221282959, 1.7938939332962036, 1.959058165550232, 1.5821685791015625, 1.7062619924545288, 1.7079789638519287, 2.157528877258301, 1.786121129989624, 1.8444347381591797, 2.010484457015991, 1.5989837646484375, 1.8498774766921997, 1.521867275238037, 1.4241461753845215, 1.3305655717849731, 1.6165968179702759, 1.8459842205047607, 1.7652475833892822, 1.778279423713684, 1.7152141332626343, 1.7055755853652954, 1.3637512922286987, 2.128040075302124, 1.7177481651306152, 1.8761051893234253, 1.6422027349472046, 1.8193389177322388, 1.689860463142395, 2.0267174243927, 1.886070966720581, 1.569051742553711, 1.9696406126022339, 